# %%
import datetime, time, math, os, json, shutil, asyncio, networkx as nx
from utils.gitutils import create_pull_request, clone_repo, create_branch, wipe_repo, prepare_repo
from utils.agent import Agent, GenerationConfig, Interaction, Team
from utils.stringutils import arr_from_sep_string, extract_markdown_blocks, markdown_to_dict
from utils.filetreeutils import FileTree, write_file_tree
from utils.listutils import flatten
from utils.frameworkutils import DartAnalyzer
from dotenv import load_dotenv
from utils.graphutils import loose_level_order, collapsed_level_order
from utils.frameworkutils import Framework

load_dotenv()  # Load environment variables from .env

GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')
API_KEY = os.getenv('API_KEY')

def failed_check_for_params(data, *params):
    for param in params:
        if not data[param]:
            return f"Error: Missing '{param}' parameter", 400
    return None

# Load the request data
repo_url = 'https://github.com/6165-MSET-CuttleFish/TeamTrack'
source = Framework.FLUTTER
target = Framework.REACT_NATIVE

# %%
# Clone the repo and make a new branch
repo = clone_repo(repo_url)
base_branch = repo.active_branch.name
created_branch = f"translation-{source}-{target}"
create_branch(repo, repo.active_branch.name, created_branch)
local_repo_path = str(repo.working_dir)
working_dir_path = f'{local_repo_path}\\{source.get_working_dir()}'

# %%
# Initialize the agent and team
target_swe = Agent(
    model_name="gemini-1.5-flash-001",
    api_key=API_KEY,
    name="target_swe",
    generation_config=GenerationConfig(temperature=0.8),
    system_prompt=f"You are a software engineer tasked with writing {target} code based on a {source} repo. Answer the following prompts to the best of your skills."
)
pm = Agent(
    model_name="gemini-1.5-flash-001",
    api_key=API_KEY,
    name="pm",
    generation_config=GenerationConfig(temperature=0.5),
    system_prompt=f"You are a high-level technical project manager tasked with the project of translating a repository from {source} to {target}. Answer the following prompts to the best of your knowledge."
)
source_swe = Agent(
    model_name="gemini-1.5-flash-001",
    api_key=API_KEY,
    name="source_swe",
    generation_config=GenerationConfig(temperature=0.7),
    system_prompt=f'''You are a {source} software engineer. Your job is to summarize the functionality of provided code files. Structure your response as follows:

# filename.ext:

$7 sentence summary of the functionality/contents of the file$
'''
)
team = Team(target_swe, pm, source_swe)

# %%
analyzer = source.get_analyzer(working_dir_path)

source_dependency_graph = analyzer.buildDependencyGraph()

# %%
# loose level order
eval_order = loose_level_order(source_dependency_graph)[::-1]
for level in eval_order:
    print(level)
print(f"Number of levels: {len(eval_order)}")
# Out:
# ['models\\AppModel.dart', 'models\\StatConfig.dart']
# ['models\\GameModel.dart']
# ['models\\ScoreModel.dart']
# ['functions\\Extensions.dart', 'components\\misc\\PlatformGraphics.dart']
# ['components\\users\\PFP.dart', 'components\\statistics\\BarGraph.dart']
# ['functions\\Statistics.dart', 'components\\scores\\ScoreSummary.dart', 'providers\\Auth.dart', 'components\\users\\UsersRow.dart', 'components\\scores\\Incrementor.dart']
# ['views\\home\\match\\MatchView.dart']
# ['components\\statistics\\PercentChange.dart', 'functions\\Functions.dart']
# ['components\\scores\\ScoreRangeSummary.dart', 'models\\Change.dart', 'components\\scores\\ScoreTimeline.dart']
# ['components\\misc\\EmptyList.dart', 'components\\scores\\ScoringElementStats.dart', 'components\\statistics\\CheckList.dart', 'views\\home\\match\\ExampleMatchRow.dart', 'views\\home\\change\\ChangeConfig.dart', 'views\\home\\change\\ChangeRow.dart', 'views\\home\\match\\MatchConfig.dart', 'views\\home\\match\\MatchRow.dart', 'components\\misc\\CardView.dart']
# ['views\\home\\match\\MatchList.dart', 'components\\misc\\Collapsible.dart', 'views\\home\\change\\ChangeList.dart', 'components\\scores\\ScoreCard.dart', 'components\\AutonomousDrawingTool.dart']
# ['views\\home\\team\\AutonDrawer.dart']
# ['views\\home\\team\\ExampleTeamRow.dart', 'views\\home\\team\\TeamView.dart', 'views\\home\\team\\TeamRow.dart', 'views\\home\\util\\Permissions.dart']
# ['views\\home\\events\\EventShare.dart', 'views\\home\\team\\TeamList.dart', 'functions\\APIMethods.dart']
# ['views\\home\\events\\EventView.dart', 'views\\auth\\SignUpScreen.dart']
# ['views\\home\\events\\EventsList.dart', 'views\\auth\\Login.dart', 'providers\\PushNotifications.dart', 'views\\inbox\\BlockList.dart', 'views\\inbox\\Inbox.dart', 'providers\\Theme.dart', 'views\\templates\\TemplatesList.dart']
# ['views\\LandingPage.dart']
# ['models\\GPTModel.dart', 'views\\auth\\AuthenticationWrapper.dart']
# ['functions\\GPTModel.dart', 'views\\home\\events\\CameraView.dart', 'functions\\ResponseModel.dart', 'views\\home\\team\\AllianceSelection.dart', 'views\\home\\events\\ImageView.dart', 'views\\templates\\TemplateView.dart', 'main.dart', 'views\\auth\\Verify.dart', 'views\\home\\team\\TeamAllianceRecommend.dart', 'api\\README.MD', 'providers\\UserPresence.dart', 'views\\home\\team\\TeamRowAlliance.dart', 'components\\misc\\InfoPills.dart', 'views\\home\\team\\AllianceSimulator.dart']
# Number of levels: 19

# %%
(source_file_tree := FileTree.from_dir(working_dir_path))
# Out:
# ├── api\
# │   ├── README.MD
# ├── components\
# │   ├── misc\
# │   │   ├── CardView.dart
# │   │   ├── Collapsible.dart
# │   │   ├── EmptyList.dart
# │   │   ├── InfoPills.dart
# │   │   ├── PlatformGraphics.dart
# │   ├── scores\
# │   │   ├── Incrementor.dart
# │   │   ├── ScoreCard.dart
# │   │   ├── ScoreRangeSummary.dart
# │   │   ├── ScoreSummary.dart
# │   │   ├── ScoreTimeline.dart
# │   │   ├── ScoringElementStats.dart
# │   ├── statistics\
# │   │   ├── BarGraph.dart
# │   │   ├── CheckList.dart
# │   │   ├── PercentChange.dart
# │   ├── users\
# │   │   ├── PFP.dart
# │   │   ├── UsersRow.dart
# │   ├── AutonomousDrawingTool.dart
# ├── functions\
# │   ├── APIMethods.dart
# │   ├── Extensions.dart
# │   ├── Functions.dart
# │   ├── GPTModel.dart
# │   ├── ResponseModel.dart
# │   ├── Statistics.dart
# ├── models\
# │   ├── AppModel.dart
# │   ├── Change.dart
# │   ├── GameModel.dart
# │   ├── GPTModel.dart
# │   ├── ScoreModel.dart
# │   ├── StatConfig.dart
# ├── providers\
# │   ├── Auth.dart
# │   ├── PushNotifications.dart
# │   ├── Theme.dart
# │   ├── UserPresence.dart
# ├── views\
# │   ├── auth\
# │   │   ├── AuthenticationWrapper.dart
# │   │   ├── Login.dart
# │   │   ├── SignUpScreen.dart
# │   │   ├── Verify.dart
# │   ├── home\
# │   │   ├── change\
# │   │   │   ├── ChangeConfig.dart
# │   │   │   ├── ChangeList.dart
# │   │   │   ├── ChangeRow.dart
# │   │   ├── events\
# │   │   │   ├── CameraView.dart
# │   │   │   ├── EventShare.dart
# │   │   │   ├── EventsList.dart
# │   │   │   ├── EventView.dart
# │   │   │   ├── ImageView.dart
# │   │   ├── match\
# │   │   │   ├── ExampleMatchRow.dart
# │   │   │   ├── MatchConfig.dart
# │   │   │   ├── MatchList.dart
# │   │   │   ├── MatchRow.dart
# │   │   │   ├── MatchView.dart
# │   │   ├── team\
# │   │   │   ├── AllianceSelection.dart
# │   │   │   ├── AllianceSimulator.dart
# │   │   │   ├── AutonDrawer.dart
# │   │   │   ├── ExampleTeamRow.dart
# │   │   │   ├── TeamAllianceRecommend.dart
# │   │   │   ├── TeamList.dart
# │   │   │   ├── TeamRow.dart
# │   │   │   ├── TeamRowAlliance.dart
# │   │   │   ├── TeamView.dart
# │   │   ├── util\
# │   │   │   ├── Permissions.dart
# │   ├── inbox\
# │   │   ├── BlockList.dart
# │   │   ├── Inbox.dart
# │   ├── templates\
# │   │   ├── TemplatesList.dart
# │   │   ├── TemplateView.dart
# │   ├── LandingPage.dart
# ├── main.dart

# %%
# Summarize the original repo
from tqdm import tqdm

async def summarize_group(group):
    async def summarize(node):
        name = source_file_tree.nodes[node]['name']
        content = source_file_tree.nodes[node]['content']
        message = f"{name}\n```\n{content}\n```"
        return await team.async_chat_with_agent(
            agent_name='source_swe',
            message=message,
            context_keys=[f"summary_{neighbor}" for neighbor in source_dependency_graph[node]],
            save_keys=[f"summary_{node}", "all"],
            prompt_title=f"Summary of {node}"
            )
    tasks = [summarize(node) for node in group]
    responses = await asyncio.gather(*tasks)
    for i, response in enumerate(responses):
        source_file_tree.nodes[group[i]]["summary"] = response

for level in tqdm(eval_order):
    await summarize_group(level)
    time.sleep(0.5)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]
# 100%|██████████| 19/19 [01:11<00:00,  3.75s/it]

# %%
curr_string = '\n'.join([message['parts'][0] for interaction in team.context_threads['all'] for message in interaction.to_dict()])
(curr_tokens := pm.model.count_tokens(curr_string).total_tokens)
# Out:
# 15863

# %%
would_be_string = '\n'.join([source_file_tree.nodes[node]['content'] for node in source_dependency_graph.nodes])
(would_be_tokens := pm.model.count_tokens(would_be_string).total_tokens)
# Out:
# 122963

# %%
(percent_tokens_reduction := 1 - (curr_tokens / would_be_tokens))
# Out:
# 0.8709937135561103

# %%
# Create new file tree
prompt = f'''This is the file tree for the original {source} repo:
```
{source.get_working_dir()}\\
{source_file_tree}
```
You are tasked with re-structuring the directory to create a file tree for the new react-native repo in the new working directory {target.get_working_dir()}\\. Format your response as follows:
# Summary of Original Repo
$less than 10 sentence summary of the original repo$

# Methodology of Translation
$Brief explanation of what needs to be translated (include things like filename changes for entry points and other structural changes)$

# File Tree
```
{target.get_working_dir()}\\
├── folder1\\
│   ├── file1.ext
├── folder2\\
│   ├── folder3\\
│   │   ├── file2.ext
```
*Only include files of type(s) {target.get_file_extensions()} in your file tree

# All Correspondances
$List all the files in the original repo and their corresponding file(s) in the new repo (N/A if no such file(s) exists)$
```
{source.get_working_dir()}\\path\\to\\{source}\\file1.ext --> {target.get_working_dir()}\\path\\to\\{target}\\file1.ext, {target.get_working_dir()}\\path\\to\\{target}\\file2.ext
{source.get_working_dir()}\\path\\to\\{source}\\file2.ext --> {target.get_working_dir()}\\path\\to\\{target}\\file3.ext
{source.get_working_dir()}\\path\\to\\{source}\\file_with_no_correspondant.ext --> N/A *do NOT provide a reason if n/a*
N/A *do NOT provide a reason if n/a* --> {target.get_working_dir()}\\path\\to\\{target}\\file_with_no_correspondant.ext
```
'''
response = team.chat_with_agent('pm', prompt, context_keys=['all'], save_keys=['all'], prompt_title=f"Translate file tree from {source} to {target}:\n```\n{source.get_working_dir()}\\\n{source_file_tree}```")

# %%
response_dict = markdown_to_dict(response)

raw_tree = extract_markdown_blocks(response_dict['file tree'])[0][len(target.get_working_dir()) + 2:]

# %%
wipe_repo(local_repo_path)
# repo.git.commit(A=True, m="rm past")
working_dir_path = f'{local_repo_path}\\{target.get_working_dir()}'
write_file_tree(raw_tree, working_dir_path)
# repo.git.commit(A=True, m="A New Hope")
(target_file_tree := FileTree.from_dir(working_dir_path))
# Out:
# ├── api\
# │   ├── APIMethods.ts
# ├── components\
# │   ├── misc\
# │   │   ├── CardView.tsx
# │   │   ├── Collapsible.tsx
# │   │   ├── EmptyList.tsx
# │   │   ├── InfoPills.tsx
# │   │   ├── PlatformGraphics.tsx
# │   ├── scores\
# │   │   ├── Incrementor.tsx
# │   │   ├── ScoreCard.tsx
# │   │   ├── ScoreRangeSummary.tsx
# │   │   ├── ScoreSummary.tsx
# │   │   ├── ScoreTimeline.tsx
# │   │   ├── ScoringElementStats.tsx
# │   ├── statistics\
# │   │   ├── BarGraph.tsx
# │   │   ├── CheckList.tsx
# │   │   ├── PercentChange.tsx
# │   ├── users\
# │   │   ├── PFP.tsx
# │   │   ├── UsersRow.tsx
# │   ├── AutonomousDrawingTool.tsx
# ├── functions\
# │   ├── APIMethods.ts
# │   ├── Extensions.ts
# │   ├── Functions.ts
# │   ├── GPTModel.ts
# │   ├── ResponseModel.ts
# │   ├── Statistics.ts
# ├── models\
# │   ├── AppModel.ts
# │   ├── Change.ts
# │   ├── GameModel.ts
# │   ├── GPTModel.ts
# │   ├── ScoreModel.ts
# │   ├── StatConfig.ts
# ├── providers\
# │   ├── Auth.ts
# │   ├── PushNotifications.ts
# │   ├── Theme.ts
# │   ├── UserPresence.ts
# ├── views\
# │   ├── auth\
# │   │   ├── AuthenticationWrapper.tsx
# │   │   ├── Login.tsx
# │   │   ├── SignUpScreen.tsx
# │   │   ├── Verify.tsx
# │   ├── home\
# │   │   ├── change\
# │   │   │   ├── ChangeConfig.tsx
# │   │   │   ├── ChangeList.tsx
# │   │   │   ├── ChangeRow.tsx
# │   │   ├── events\
# │   │   │   ├── CameraView.tsx
# │   │   │   ├── EventShare.tsx
# │   │   │   ├── EventsList.tsx
# │   │   │   ├── EventView.tsx
# │   │   │   ├── ImageView.tsx
# │   │   ├── match\
# │   │   │   ├── ExampleMatchRow.tsx
# │   │   │   ├── MatchConfig.tsx
# │   │   │   ├── MatchList.tsx
# │   │   │   ├── MatchRow.tsx
# │   │   │   ├── MatchView.tsx
# │   │   ├── team\
# │   │   │   ├── AllianceSelection.tsx
# │   │   │   ├── AllianceSimulator.tsx
# │   │   │   ├── AutonDrawer.tsx
# │   │   │   ├── ExampleTeamRow.tsx
# │   │   │   ├── TeamAllianceRecommend.tsx
# │   │   │   ├── TeamList.tsx
# │   │   │   ├── TeamRow.tsx
# │   │   │   ├── TeamRowAlliance.tsx
# │   │   │   ├── TeamView.tsx
# │   │   ├── util\
# │   │   │   ├── Permissions.tsx
# │   ├── inbox\
# │   │   ├── BlockList.tsx
# │   │   ├── Inbox.tsx
# │   ├── templates\
# │   │   ├── TemplatesList.tsx
# │   │   ├── TemplateView.tsx
# │   ├── LandingPage.tsx
# ├── index.js

# %%
correspondance_graph = nx.Graph()
correspondences = arr_from_sep_string(extract_markdown_blocks(response_dict['all correspondances'])[0], '\n')
for correspondence in correspondences:
    source_file, target_files = arr_from_sep_string(correspondence, ' --> ')
    if target_files == "N/A": continue
    source_file = source_file[len(source.get_working_dir()) + 1:]
    if not source_file_tree.has_node(source_file): continue
    target_files = arr_from_sep_string(target_files)
    for target_file in target_files:
        target_file = target_file[len(target.get_working_dir()) + 1:]
        if not target_file_tree.has_node(target_file): continue
        correspondance_graph.add_edge(source_file, target_file)

# print edges
for edge in correspondance_graph.edges:
    print(edge)
# Out:
# ('components\\misc\\CardView.dart', 'components\\misc\\CardView.tsx')
# ('components\\misc\\Collapsible.dart', 'components\\misc\\Collapsible.tsx')
# ('components\\misc\\EmptyList.dart', 'components\\misc\\EmptyList.tsx')
# ('components\\misc\\InfoPills.dart', 'components\\misc\\InfoPills.tsx')
# ('components\\misc\\PlatformGraphics.dart', 'components\\misc\\PlatformGraphics.tsx')
# ('components\\scores\\Incrementor.dart', 'components\\scores\\Incrementor.tsx')
# ('components\\scores\\ScoreCard.dart', 'components\\scores\\ScoreCard.tsx')
# ('components\\scores\\ScoreRangeSummary.dart', 'components\\scores\\ScoreRangeSummary.tsx')
# ('components\\scores\\ScoreSummary.dart', 'components\\scores\\ScoreSummary.tsx')
# ('components\\scores\\ScoreTimeline.dart', 'components\\scores\\ScoreTimeline.tsx')
# ('components\\scores\\ScoringElementStats.dart', 'components\\scores\\ScoringElementStats.tsx')
# ('components\\statistics\\BarGraph.dart', 'components\\statistics\\BarGraph.tsx')
# ('components\\statistics\\CheckList.dart', 'components\\statistics\\CheckList.tsx')
# ('components\\statistics\\PercentChange.dart', 'components\\statistics\\PercentChange.tsx')
# ('components\\users\\PFP.dart', 'components\\users\\PFP.tsx')
# ('components\\users\\UsersRow.dart', 'components\\users\\UsersRow.tsx')
# ('components\\AutonomousDrawingTool.dart', 'components\\AutonomousDrawingTool.tsx')
# ('functions\\APIMethods.dart', 'api\\APIMethods.ts')
# ('functions\\APIMethods.dart', 'functions\\APIMethods.ts')
# ('functions\\Extensions.dart', 'functions\\Extensions.ts')
# ('functions\\Functions.dart', 'functions\\Functions.ts')
# ('functions\\GPTModel.dart', 'functions\\GPTModel.ts')
# ('functions\\ResponseModel.dart', 'functions\\ResponseModel.ts')
# ('functions\\Statistics.dart', 'functions\\Statistics.ts')
# ('models\\AppModel.dart', 'models\\AppModel.ts')
# ('models\\Change.dart', 'models\\Change.ts')
# ('models\\GameModel.dart', 'models\\GameModel.ts')
# ('models\\GPTModel.dart', 'models\\GPTModel.ts')
# ('models\\ScoreModel.dart', 'models\\ScoreModel.ts')
# ('models\\StatConfig.dart', 'models\\StatConfig.ts')
# ('providers\\Auth.dart', 'providers\\Auth.ts')
# ('providers\\PushNotifications.dart', 'providers\\PushNotifications.ts')
# ('providers\\Theme.dart', 'providers\\Theme.ts')
# ('providers\\UserPresence.dart', 'providers\\UserPresence.ts')
# ('views\\auth\\AuthenticationWrapper.dart', 'views\\auth\\AuthenticationWrapper.tsx')
# ('views\\auth\\Login.dart', 'views\\auth\\Login.tsx')
# ('views\\auth\\SignUpScreen.dart', 'views\\auth\\SignUpScreen.tsx')
# ('views\\auth\\Verify.dart', 'views\\auth\\Verify.tsx')
# ('views\\home\\change\\ChangeConfig.dart', 'views\\home\\change\\ChangeConfig.tsx')
# ('views\\home\\change\\ChangeList.dart', 'views\\home\\change\\ChangeList.tsx')
# ('views\\home\\change\\ChangeRow.dart', 'views\\home\\change\\ChangeRow.tsx')
# ('views\\home\\events\\CameraView.dart', 'views\\home\\events\\CameraView.tsx')
# ('views\\home\\events\\EventShare.dart', 'views\\home\\events\\EventShare.tsx')
# ('views\\home\\events\\EventsList.dart', 'views\\home\\events\\EventsList.tsx')
# ('views\\home\\events\\EventView.dart', 'views\\home\\events\\EventView.tsx')
# ('views\\home\\events\\ImageView.dart', 'views\\home\\events\\ImageView.tsx')
# ('views\\home\\match\\ExampleMatchRow.dart', 'views\\home\\match\\ExampleMatchRow.tsx')
# ('views\\home\\match\\MatchConfig.dart', 'views\\home\\match\\MatchConfig.tsx')
# ('views\\home\\match\\MatchList.dart', 'views\\home\\match\\MatchList.tsx')
# ('views\\home\\match\\MatchRow.dart', 'views\\home\\match\\MatchRow.tsx')
# ('views\\home\\match\\MatchView.dart', 'views\\home\\match\\MatchView.tsx')
# ('views\\home\\team\\AllianceSelection.dart', 'views\\home\\team\\AllianceSelection.tsx')
# ('views\\home\\team\\AllianceSimulator.dart', 'views\\home\\team\\AllianceSimulator.tsx')
# ('views\\home\\team\\AutonDrawer.dart', 'views\\home\\team\\AutonDrawer.tsx')
# ('views\\home\\team\\ExampleTeamRow.dart', 'views\\home\\team\\ExampleTeamRow.tsx')
# ('views\\home\\team\\TeamAllianceRecommend.dart', 'views\\home\\team\\TeamAllianceRecommend.tsx')
# ('views\\home\\team\\TeamList.dart', 'views\\home\\team\\TeamList.tsx')
# ('views\\home\\team\\TeamRow.dart', 'views\\home\\team\\TeamRow.tsx')
# ('views\\home\\team\\TeamRowAlliance.dart', 'views\\home\\team\\TeamRowAlliance.tsx')
# ('views\\home\\team\\TeamView.dart', 'views\\home\\team\\TeamView.tsx')
# ('views\\home\\util\\Permissions.dart', 'views\\home\\util\\Permissions.tsx')
# ('views\\inbox\\BlockList.dart', 'views\\inbox\\BlockList.tsx')
# ('views\\inbox\\Inbox.dart', 'views\\inbox\\Inbox.tsx')
# ('views\\templates\\TemplatesList.dart', 'views\\templates\\TemplatesList.tsx')
# ('views\\templates\\TemplateView.dart', 'views\\templates\\TemplateView.tsx')
# ('views\\LandingPage.dart', 'views\\LandingPage.tsx')
# ('main.dart', 'index.js')

# %%
pm.model.count_tokens('\n'.join(message['parts'][0] for interaction in team.context_threads['all'] for message in interaction.to_dict())).total_tokens
# Out:
# 19223

# %%
import datetime, math
# Cache the context threads
factor = 32768 / pm.model.count_tokens('\n'.join(message['parts'][0] for interaction in team.context_threads['all'] for message in interaction.to_dict())).total_tokens
# eg. if factor is 3.2, round to 4
factor = math.ceil(factor)
team.context_threads['all'] *= factor
pm.model.count_tokens('\n'.join(message['parts'][0] for interaction in team.context_threads['all'] for message in interaction.to_dict())).total_tokens
# Out:
# 38412

# %%
pm.cache_context(team.context_threads['all'], ttl=datetime.timedelta(minutes=5))

# %%
order = [node for node in target_file_tree.nodes if 'content' in target_file_tree.nodes[node]]
async def build_description(node):
    prompt = f'''For the file {node} in the new {target} repo. I want you to provide the following write-up:
$A brief description of what the file should contain (classes, functions, views etc.) in 20 lines or less$
$Example usage$
''' 
    return await team.async_chat_with_agent('pm', prompt, save_keys=[f"description_{node}"], prompt_title=f"Description of what to build for {node}")
tasks = [build_description(node) for node in order]
descriptions = await asyncio.gather(*tasks)
for i, description in enumerate(descriptions):
    target_file_tree.nodes[order[i]]['description'] = description

# %%
# Create a dependency graph for the target repo
target_dependency_graph = nx.DiGraph()
for level in eval_order:
    for node in level:
        if node not in correspondance_graph.nodes: continue
        # We add the correspondant node to the target dependency graph and connect it to the correspondant nodes of the source dependency graph
        target_nodes = list(correspondance_graph[node])
        for target_node in target_nodes:
            target_node = target_node
            target_dependency_graph.add_node(target_node)
            for source_node in source_dependency_graph[node]:
                if source_node not in correspondance_graph.nodes: continue
                source_node_correspondants = list(correspondance_graph[source_node])
                for source_node_correspondant in source_node_correspondants:
                    target_dependency_graph.add_edge(target_node, source_node_correspondant)

# %%
# label each node in target dependency graph with a description
for node in target_dependency_graph.nodes:
    target_dependency_graph.nodes[node]['description'] = ""
    if node not in target_file_tree.nodes:
        # maybe remove the node from the target dependency graph
        continue
    if 'content' not in target_file_tree.nodes[node]: continue
    description = target_file_tree.nodes[node]['description']
    target_dependency_graph.nodes[node]['description'] = description

# %%
target_eval_order = loose_level_order(target_dependency_graph, key='description')[::-1]
for level in target_eval_order:
    print(level)
print(f"Number of levels: {len(target_eval_order)}")
# Out:
# ['models\\AppModel.ts']
# ['models\\StatConfig.ts', 'functions\\Extensions.ts']
# ['components\\misc\\PlatformGraphics.tsx', 'models\\GameModel.ts']
# ['models\\ScoreModel.ts', 'components\\statistics\\BarGraph.tsx', 'components\\users\\PFP.tsx']
# ['components\\scores\\Incrementor.tsx', 'components\\users\\UsersRow.tsx', 'components\\scores\\ScoreSummary.tsx', 'functions\\Statistics.ts', 'providers\\Auth.ts']
# ['views\\home\\match\\MatchView.tsx']
# ['components\\statistics\\PercentChange.tsx', 'functions\\Functions.ts']
# ['components\\scores\\ScoreTimeline.tsx', 'components\\scores\\ScoreRangeSummary.tsx', 'models\\Change.ts']
# ['views\\home\\match\\ExampleMatchRow.tsx', 'components\\scores\\ScoringElementStats.tsx', 'components\\misc\\CardView.tsx', 'views\\home\\match\\MatchRow.tsx', 'views\\home\\match\\MatchConfig.tsx', 'components\\statistics\\CheckList.tsx', 'views\\home\\change\\ChangeRow.tsx', 'components\\misc\\EmptyList.tsx', 'views\\home\\change\\ChangeConfig.tsx']
# ['components\\scores\\ScoreCard.tsx', 'components\\misc\\Collapsible.tsx', 'views\\home\\change\\ChangeList.tsx', 'components\\AutonomousDrawingTool.tsx', 'views\\home\\match\\MatchList.tsx']
# ['views\\home\\team\\AutonDrawer.tsx']
# ['views\\home\\team\\ExampleTeamRow.tsx', 'views\\home\\team\\TeamView.tsx', 'views\\home\\util\\Permissions.tsx', 'views\\home\\team\\TeamRow.tsx']
# ['views\\home\\team\\TeamList.tsx', 'views\\home\\events\\EventShare.tsx', 'functions\\APIMethods.ts', 'api\\APIMethods.ts']
# ['views\\home\\events\\EventView.tsx', 'views\\auth\\SignUpScreen.tsx']
# ['views\\inbox\\BlockList.tsx', 'providers\\PushNotifications.ts', 'views\\inbox\\Inbox.tsx', 'views\\templates\\TemplatesList.tsx', 'providers\\Theme.ts', 'views\\home\\events\\EventsList.tsx', 'views\\auth\\Login.tsx']
# ['views\\LandingPage.tsx']
# ['views\\auth\\AuthenticationWrapper.tsx', 'models\\GPTModel.ts']
# ['functions\\GPTModel.ts', 'views\\home\\team\\AllianceSimulator.tsx', 'views\\home\\team\\AllianceSelection.tsx', 'functions\\ResponseModel.ts', 'providers\\UserPresence.ts', 'views\\home\\events\\CameraView.tsx', 'views\\home\\team\\TeamRowAlliance.tsx', 'views\\home\\events\\ImageView.tsx', 'views\\auth\\Verify.tsx', 'views\\home\\team\\TeamAllianceRecommend.tsx', 'views\\templates\\TemplateView.tsx', 'components\\misc\\InfoPills.tsx', 'index.js']
# Number of levels: 18

# %%
# print all relative paths
for level in target_eval_order:
    for node in level:
        print(node)
        print(f"Relevant files: {list(correspondance_graph[node])}")
        print(f"Depends on: {list(target_dependency_graph[node])}")
        dependencies = '\n'.join(os.path.relpath(target_file_tree.nodes[file]['path'], os.path.dirname(target_file_tree.nodes[node]['path'])) for file in target_dependency_graph[node])
        print(f"Dependencies: {dependencies}")
        print("-" * 20)
    print('-' * 20)
# Out:
# models\AppModel.ts
# Relevant files: ['models\\AppModel.dart']
# Depends on: ['functions\\Functions.ts']
# Dependencies: ..\..\functions\Functions.ts
# --------------------
# --------------------
# models\StatConfig.ts
# Relevant files: ['models\\StatConfig.dart']
# Depends on: []
# Dependencies:
# --------------------
# functions\Extensions.ts
# Relevant files: ['functions\\Extensions.dart']
# Depends on: ['models\\AppModel.ts', 'models\\GameModel.ts', 'models\\ScoreModel.ts']
# Dependencies: ..\..\models\AppModel.ts
# ..\..\models\GameModel.ts
# ..\..\models\ScoreModel.ts
# --------------------
# --------------------
# components\misc\PlatformGraphics.tsx
# Relevant files: ['components\\misc\\PlatformGraphics.dart']
# Depends on: []
# Dependencies:
# --------------------
# models\GameModel.ts
# Relevant files: ['models\\GameModel.dart']
# Depends on: ['functions\\Functions.ts', 'models\\AppModel.ts', 'models\\Change.ts', 'models\\StatConfig.ts', 'functions\\Extensions.ts', 'functions\\Statistics.ts']
# Dependencies: ..\..\functions\Functions.ts
# ..\AppModel.ts
# ..\Change.ts
# ..\StatConfig.ts
# ..\..\functions\Extensions.ts
# ..\..\functions\Statistics.ts
# --------------------
# --------------------
# models\ScoreModel.ts
# Relevant files: ['models\\ScoreModel.dart']
# Depends on: ['models\\AppModel.ts', 'models\\GameModel.ts', 'functions\\Extensions.ts', 'functions\\Statistics.ts']
# Dependencies: ..\AppModel.ts
# ..\GameModel.ts
# ..\..\functions\Extensions.ts
# ..\..\functions\Statistics.ts
# --------------------
# components\statistics\BarGraph.tsx
# Relevant files: ['components\\statistics\\BarGraph.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx']
# Dependencies: ..\..\misc\PlatformGraphics.tsx
# --------------------
# components\users\PFP.tsx
# Relevant files: ['components\\users\\PFP.dart']
# Depends on: ['models\\AppModel.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\..\models\AppModel.ts
# ..\..\..\functions\Extensions.ts
# --------------------
# --------------------
# components\scores\Incrementor.tsx
# Relevant files: ['components\\scores\\Incrementor.dart']
# Depends on: ['components\\statistics\\BarGraph.tsx', 'components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'models\\GameModel.ts', 'models\\ScoreModel.ts']
# Dependencies: ..\..\statistics\BarGraph.tsx
# ..\..\misc\PlatformGraphics.tsx
# ..\..\..\models\AppModel.ts
# ..\..\..\models\GameModel.ts
# ..\..\..\models\ScoreModel.ts
# --------------------
# components\users\UsersRow.tsx
# Relevant files: ['components\\users\\UsersRow.dart']
# Depends on: ['components\\users\\PFP.tsx', 'models\\AppModel.ts']
# Dependencies: ..\PFP.tsx
# ..\..\..\models\AppModel.ts
# --------------------
# components\scores\ScoreSummary.tsx
# Relevant files: ['components\\scores\\ScoreSummary.dart']
# Depends on: ['components\\statistics\\BarGraph.tsx', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\statistics\BarGraph.tsx
# ..\..\..\models\GameModel.ts
# ..\..\..\models\ScoreModel.ts
# ..\..\..\functions\Extensions.ts
# --------------------
# functions\Statistics.ts
# Relevant files: ['functions\\Statistics.dart']
# Depends on: ['models\\GameModel.ts', 'models\\ScoreModel.ts', 'models\\StatConfig.ts']
# Dependencies: ..\..\models\GameModel.ts
# ..\..\models\ScoreModel.ts
# ..\..\models\StatConfig.ts
# --------------------
# providers\Auth.ts
# Relevant files: ['providers\\Auth.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts']
# Dependencies: ..\..\components\misc\PlatformGraphics.tsx
# ..\..\models\AppModel.ts
# --------------------
# --------------------
# views\home\match\MatchView.tsx
# Relevant files: ['views\\home\\match\\MatchView.dart']
# Depends on: ['components\\statistics\\BarGraph.tsx', 'components\\scores\\Incrementor.tsx', 'components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'functions\\Statistics.ts', 'providers\\Auth.ts', 'components\\scores\\ScoreSummary.tsx', 'components\\users\\UsersRow.tsx', 'functions\\Extensions.ts']
# Dependencies: ..\..\..\..\components\statistics\BarGraph.tsx
# ..\..\..\..\components\scores\Incrementor.tsx
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\providers\Auth.ts
# ..\..\..\..\components\scores\ScoreSummary.tsx
# ..\..\..\..\components\users\UsersRow.tsx
# ..\..\..\..\functions\Extensions.ts
# --------------------
# --------------------
# components\statistics\PercentChange.tsx
# Relevant files: ['components\\statistics\\PercentChange.dart']
# Depends on: []
# Dependencies:
# --------------------
# functions\Functions.ts
# Relevant files: ['functions\\Functions.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'models\\GameModel.ts', 'views\\home\\match\\MatchView.tsx']
# Dependencies: ..\..\components\misc\PlatformGraphics.tsx
# ..\..\models\AppModel.ts
# ..\..\models\GameModel.ts
# ..\..\views\home\match\MatchView.tsx
# --------------------
# --------------------
# components\scores\ScoreTimeline.tsx
# Relevant files: ['components\\scores\\ScoreTimeline.dart']
# Depends on: ['functions\\Statistics.ts']
# Dependencies: ..\..\..\functions\Statistics.ts
# --------------------
# components\scores\ScoreRangeSummary.tsx
# Relevant files: ['components\\scores\\ScoreRangeSummary.dart']
# Depends on: ['components\\statistics\\PercentChange.tsx', 'functions\\Extensions.ts', 'models\\ScoreModel.ts', 'functions\\Statistics.ts']
# Dependencies: ..\..\statistics\PercentChange.tsx
# ..\..\..\functions\Extensions.ts
# ..\..\..\models\ScoreModel.ts
# ..\..\..\functions\Statistics.ts
# --------------------
# models\Change.ts
# Relevant files: ['models\\Change.dart']
# Depends on: ['functions\\Functions.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\functions\Functions.ts
# ..\..\functions\Extensions.ts
# --------------------
# --------------------
# views\home\match\ExampleMatchRow.tsx
# Relevant files: ['views\\home\\match\\ExampleMatchRow.dart']
# Depends on: ['models\\GameModel.ts']
# Dependencies: ..\..\..\..\models\GameModel.ts
# --------------------
# components\scores\ScoringElementStats.tsx
# Relevant files: ['components\\scores\\ScoringElementStats.dart']
# Depends on: ['components\\scores\\ScoreTimeline.tsx', 'components\\statistics\\BarGraph.tsx', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'functions\\Extensions.ts', 'functions\\Statistics.ts']
# Dependencies: ..\ScoreTimeline.tsx
# ..\..\statistics\BarGraph.tsx
# ..\..\..\models\GameModel.ts
# ..\..\..\models\ScoreModel.ts
# ..\..\..\functions\Extensions.ts
# ..\..\..\functions\Statistics.ts
# --------------------
# components\misc\CardView.tsx
# Relevant files: ['components\\misc\\CardView.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\GameModel.ts', 'functions\\Extensions.ts']
# Dependencies: ..\PlatformGraphics.tsx
# ..\..\..\models\GameModel.ts
# ..\..\..\functions\Extensions.ts
# --------------------
# views\home\match\MatchRow.tsx
# Relevant files: ['views\\home\\match\\MatchRow.dart']
# Depends on: ['components\\users\\UsersRow.tsx', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'models\\StatConfig.ts', 'components\\scores\\ScoreSummary.tsx']
# Dependencies: ..\..\..\..\components\users\UsersRow.tsx
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\models\StatConfig.ts
# ..\..\..\..\components\scores\ScoreSummary.tsx
# --------------------
# views\home\match\MatchConfig.tsx
# Relevant files: ['views\\home\\match\\MatchConfig.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\GameModel.ts', 'functions\\Statistics.ts']
# Dependencies: ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\functions\Statistics.ts
# --------------------
# components\statistics\CheckList.tsx
# Relevant files: ['components\\statistics\\CheckList.dart']
# Depends on: ['models\\GameModel.ts', 'models\\StatConfig.ts']
# Dependencies: ..\..\..\models\GameModel.ts
# ..\..\..\models\StatConfig.ts
# --------------------
# views\home\change\ChangeRow.tsx
# Relevant files: ['views\\home\\change\\ChangeRow.dart']
# Depends on: ['components\\scores\\ScoreRangeSummary.tsx', 'models\\Change.ts', 'models\\GameModel.ts']
# Dependencies: ..\..\..\..\components\scores\ScoreRangeSummary.tsx
# ..\..\..\..\models\Change.ts
# ..\..\..\..\models\GameModel.ts
# --------------------
# components\misc\EmptyList.tsx
# Relevant files: ['components\\misc\\EmptyList.dart']
# Depends on: []
# Dependencies:
# --------------------
# views\home\change\ChangeConfig.tsx
# Relevant files: ['views\\home\\change\\ChangeConfig.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'models\\Change.ts', 'models\\GameModel.ts']
# Dependencies: ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\models\Change.ts
# ..\..\..\..\models\GameModel.ts
# --------------------
# --------------------
# components\scores\ScoreCard.tsx
# Relevant files: ['components\\scores\\ScoreCard.dart']
# Depends on: ['components\\scores\\ScoreTimeline.tsx', 'components\\scores\\ScoringElementStats.tsx', 'functions\\Extensions.ts', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'components\\statistics\\BarGraph.tsx', 'components\\misc\\CardView.tsx', 'functions\\Statistics.ts']
# Dependencies: ..\ScoreTimeline.tsx
# ..\ScoringElementStats.tsx
# ..\..\..\functions\Extensions.ts
# ..\..\..\models\GameModel.ts
# ..\..\..\models\ScoreModel.ts
# ..\..\statistics\BarGraph.tsx
# ..\..\misc\CardView.tsx
# ..\..\..\functions\Statistics.ts
# --------------------
# components\misc\Collapsible.tsx
# Relevant files: ['components\\misc\\Collapsible.dart']
# Depends on: []
# Dependencies:
# --------------------
# views\home\change\ChangeList.tsx
# Relevant files: ['views\\home\\change\\ChangeList.dart']
# Depends on: ['models\\AppModel.ts', 'components\\misc\\PlatformGraphics.tsx', 'models\\GameModel.ts', 'views\\home\\change\\ChangeConfig.tsx', 'views\\home\\change\\ChangeRow.tsx']
# Dependencies: ..\..\..\..\models\AppModel.ts
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\models\GameModel.ts
# ..\ChangeConfig.tsx
# ..\ChangeRow.tsx
# --------------------
# components\AutonomousDrawingTool.tsx
# Relevant files: ['components\\AutonomousDrawingTool.dart']
# Depends on: ['models\\GameModel.ts']
# Dependencies: ..\..\models\GameModel.ts
# --------------------
# views\home\match\MatchList.tsx
# Relevant files: ['views\\home\\match\\MatchList.dart']
# Depends on: ['components\\misc\\EmptyList.tsx', 'functions\\Functions.ts', 'models\\GameModel.ts', 'models\\StatConfig.ts', 'views\\home\\match\\ExampleMatchRow.tsx', 'views\\home\\match\\MatchConfig.tsx', 'views\\home\\match\\MatchRow.tsx', 'models\\AppModel.ts', 'components\\misc\\PlatformGraphics.tsx', 'functions\\Statistics.ts', 'functions\\Extensions.ts', 'components\\statistics\\CheckList.tsx']
# Dependencies: ..\..\..\..\components\misc\EmptyList.tsx
# ..\..\..\..\functions\Functions.ts
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\models\StatConfig.ts
# ..\ExampleMatchRow.tsx
# ..\MatchConfig.tsx
# ..\MatchRow.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\components\statistics\CheckList.tsx
# --------------------
# --------------------
# views\home\team\AutonDrawer.tsx
# Relevant files: ['views\\home\\team\\AutonDrawer.dart']
# Depends on: ['components\\misc\\Collapsible.tsx', 'components\\misc\\EmptyList.tsx', 'components\\misc\\PlatformGraphics.tsx', 'components\\scores\\ScoreCard.tsx', 'models\\GameModel.ts', 'views\\home\\change\\ChangeList.tsx', 'views\\home\\match\\MatchList.tsx', 'views\\home\\match\\MatchView.tsx', 'models\\AppModel.ts', 'models\\ScoreModel.ts', 'components\\statistics\\CheckList.tsx', 'functions\\Statistics.ts', 'functions\\Extensions.ts', 'components\\AutonomousDrawingTool.tsx']
# Dependencies: ..\..\..\..\components\misc\Collapsible.tsx
# ..\..\..\..\components\misc\EmptyList.tsx
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\components\scores\ScoreCard.tsx
# ..\..\..\..\models\GameModel.ts
# ..\..\change\ChangeList.tsx
# ..\..\match\MatchList.tsx
# ..\..\match\MatchView.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\components\statistics\CheckList.tsx
# ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\components\AutonomousDrawingTool.tsx
# --------------------
# --------------------
# views\home\team\ExampleTeamRow.tsx
# Relevant files: ['views\\home\\team\\ExampleTeamRow.dart']
# Depends on: ['functions\\Statistics.ts', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\functions\Extensions.ts
# --------------------
# views\home\team\TeamView.tsx
# Relevant files: ['views\\home\\team\\TeamView.dart']
# Depends on: ['components\\misc\\Collapsible.tsx', 'components\\misc\\EmptyList.tsx', 'components\\misc\\PlatformGraphics.tsx', 'components\\scores\\ScoreCard.tsx', 'models\\GameModel.ts', 'views\\home\\change\\ChangeList.tsx', 'views\\home\\match\\MatchList.tsx', 'views\\home\\match\\MatchView.tsx', 'models\\AppModel.ts', 'models\\ScoreModel.ts', 'components\\statistics\\CheckList.tsx', 'views\\home\\team\\AutonDrawer.tsx', 'functions\\Statistics.ts', 'functions\\Extensions.ts', 'components\\AutonomousDrawingTool.tsx']
# Dependencies: ..\..\..\..\components\misc\Collapsible.tsx
# ..\..\..\..\components\misc\EmptyList.tsx
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\components\scores\ScoreCard.tsx
# ..\..\..\..\models\GameModel.ts
# ..\..\change\ChangeList.tsx
# ..\..\match\MatchList.tsx
# ..\..\match\MatchView.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\components\statistics\CheckList.tsx
# ..\AutonDrawer.tsx
# ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\components\AutonomousDrawingTool.tsx
# --------------------
# views\home\util\Permissions.tsx
# Relevant files: ['views\\home\\util\\Permissions.dart']
# Depends on: ['components\\users\\PFP.tsx', 'components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'functions\\Extensions.ts', 'models\\GameModel.ts']
# Dependencies: ..\..\..\..\components\users\PFP.tsx
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\models\GameModel.ts
# --------------------
# views\home\team\TeamRow.tsx
# Relevant files: ['views\\home\\team\\TeamRow.dart']
# Depends on: ['components\\statistics\\BarGraph.tsx', 'components\\statistics\\PercentChange.tsx', 'models\\GameModel.ts', 'functions\\Statistics.ts', 'models\\ScoreModel.ts', 'models\\StatConfig.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\..\..\components\statistics\BarGraph.tsx
# ..\..\..\..\components\statistics\PercentChange.tsx
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\models\StatConfig.ts
# ..\..\..\..\functions\Extensions.ts
# --------------------
# --------------------
# views\home\team\TeamList.tsx
# Relevant files: ['views\\home\\team\\TeamList.dart']
# Depends on: ['components\\misc\\EmptyList.tsx', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'models\\StatConfig.ts', 'views\\home\\team\\ExampleTeamRow.tsx', 'views\\home\\team\\TeamRow.tsx', 'views\\home\\team\\TeamView.tsx', 'models\\AppModel.ts', 'components\\misc\\PlatformGraphics.tsx', 'functions\\Statistics.ts']
# Dependencies: ..\..\..\..\components\misc\EmptyList.tsx
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\models\StatConfig.ts
# ..\ExampleTeamRow.tsx
# ..\TeamRow.tsx
# ..\TeamView.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\functions\Statistics.ts
# --------------------
# views\home\events\EventShare.tsx
# Relevant files: ['views\\home\\events\\EventShare.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'functions\\Extensions.ts', 'models\\GameModel.ts', 'views\\home\\util\\Permissions.tsx']
# Dependencies: ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\models\GameModel.ts
# ..\..\util\Permissions.tsx
# --------------------
# functions\APIMethods.ts
# Relevant files: ['functions\\APIMethods.dart']
# Depends on: []
# Dependencies:
# --------------------
# api\APIMethods.ts
# Relevant files: ['functions\\APIMethods.dart']
# Depends on: []
# Dependencies:
# --------------------
# --------------------
# views\home\events\EventView.tsx
# Relevant files: ['views\\home\\events\\EventView.dart']
# Depends on: ['models\\GameModel.ts', 'models\\ScoreModel.ts', 'views\\home\\match\\MatchConfig.tsx', 'views\\home\\match\\MatchList.tsx', 'components\\statistics\\CheckList.tsx', 'views\\home\\team\\TeamList.tsx', 'functions\\Extensions.ts', 'models\\AppModel.ts', 'components\\misc\\PlatformGraphics.tsx', 'functions\\Statistics.ts', 'views\\home\\events\\EventShare.tsx', 'api\\APIMethods.ts', 'functions\\APIMethods.ts']
# Dependencies: ..\..\..\..\models\GameModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\match\MatchConfig.tsx
# ..\..\match\MatchList.tsx
# ..\..\..\..\components\statistics\CheckList.tsx
# ..\..\team\TeamList.tsx
# ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\functions\Statistics.ts
# ..\EventShare.tsx
# ..\..\..\..\api\APIMethods.ts
# ..\..\..\..\functions\APIMethods.ts
# --------------------
# views\auth\SignUpScreen.tsx
# Relevant files: ['views\\auth\\SignUpScreen.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'providers\\Auth.ts']
# Dependencies: ..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\providers\Auth.ts
# --------------------
# --------------------
# views\inbox\BlockList.tsx
# Relevant files: ['views\\inbox\\BlockList.dart']
# Depends on: ['components\\users\\PFP.tsx', 'components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'components\\misc\\EmptyList.tsx']
# Dependencies: ..\..\..\components\users\PFP.tsx
# ..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\models\AppModel.ts
# ..\..\..\components\misc\EmptyList.tsx
# --------------------
# providers\PushNotifications.ts
# Relevant files: ['providers\\PushNotifications.dart']
# Depends on: ['models\\AppModel.ts']
# Dependencies: ..\..\models\AppModel.ts
# --------------------
# views\inbox\Inbox.tsx
# Relevant files: ['views\\inbox\\Inbox.dart']
# Depends on: ['components\\misc\\EmptyList.tsx', 'components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'models\\GameModel.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\..\components\misc\EmptyList.tsx
# ..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\models\AppModel.ts
# ..\..\..\models\GameModel.ts
# ..\..\..\functions\Extensions.ts
# --------------------
# views\templates\TemplatesList.tsx
# Relevant files: ['views\\templates\\TemplatesList.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'components\\statistics\\BarGraph.tsx', 'models\\AppModel.ts', 'models\\GameModel.ts', 'api\\APIMethods.ts', 'functions\\APIMethods.ts']
# Dependencies: ..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\components\statistics\BarGraph.tsx
# ..\..\..\models\AppModel.ts
# ..\..\..\models\GameModel.ts
# ..\..\..\api\APIMethods.ts
# ..\..\..\functions\APIMethods.ts
# --------------------
# providers\Theme.ts
# Relevant files: ['providers\\Theme.dart']
# Depends on: []
# Dependencies:
# --------------------
# views\home\events\EventsList.tsx
# Relevant files: ['views\\home\\events\\EventsList.dart']
# Depends on: ['models\\GameModel.ts', 'views\\home\\events\\EventShare.tsx', 'models\\AppModel.ts', 'components\\misc\\PlatformGraphics.tsx', 'views\\home\\events\\EventView.tsx', 'functions\\Extensions.ts']
# Dependencies: ..\..\..\..\models\GameModel.ts
# ..\EventShare.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\EventView.tsx
# ..\..\..\..\functions\Extensions.ts
# --------------------
# views\auth\Login.tsx
# Relevant files: ['views\\auth\\Login.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'views\\auth\\SignUpScreen.tsx', 'providers\\Auth.ts']
# Dependencies: ..\..\..\components\misc\PlatformGraphics.tsx
# ..\SignUpScreen.tsx
# ..\..\..\providers\Auth.ts
# --------------------
# --------------------
# views\LandingPage.tsx
# Relevant files: ['views\\LandingPage.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'models\\GameModel.ts', 'providers\\Auth.ts', 'providers\\PushNotifications.ts', 'providers\\Theme.ts', 'views\\auth\\Login.tsx', 'views\\home\\events\\EventsList.tsx', 'views\\inbox\\BlockList.tsx', 'views\\inbox\\Inbox.tsx', 'views\\templates\\TemplatesList.tsx']
# Dependencies: ..\..\components\misc\PlatformGraphics.tsx
# ..\..\models\AppModel.ts
# ..\..\models\GameModel.ts
# ..\..\providers\Auth.ts
# ..\..\providers\PushNotifications.ts
# ..\..\providers\Theme.ts
# ..\auth\Login.tsx
# ..\home\events\EventsList.tsx
# ..\inbox\BlockList.tsx
# ..\inbox\Inbox.tsx
# ..\templates\TemplatesList.tsx
# --------------------
# --------------------
# views\auth\AuthenticationWrapper.tsx
# Relevant files: ['views\\auth\\AuthenticationWrapper.dart']
# Depends on: ['views\\LandingPage.tsx']
# Dependencies: ..\..\LandingPage.tsx
# --------------------
# models\GPTModel.ts
# Relevant files: ['models\\GPTModel.dart']
# Depends on: ['functions\\Functions.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\functions\Functions.ts
# ..\..\functions\Extensions.ts
# --------------------
# --------------------
# functions\GPTModel.ts
# Relevant files: ['functions\\GPTModel.dart']
# Depends on: []
# Dependencies:
# --------------------
# views\home\team\AllianceSimulator.tsx
# Relevant files: ['views\\home\\team\\AllianceSimulator.dart']
# Depends on: []
# Dependencies:
# --------------------
# views\home\team\AllianceSelection.tsx
# Relevant files: ['views\\home\\team\\AllianceSelection.dart']
# Depends on: ['functions\\Extensions.ts', 'functions\\Statistics.ts', 'models\\GPTModel.ts']
# Dependencies: ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\models\GPTModel.ts
# --------------------
# functions\ResponseModel.ts
# Relevant files: ['functions\\ResponseModel.dart']
# Depends on: []
# Dependencies:
# --------------------
# providers\UserPresence.ts
# Relevant files: ['providers\\UserPresence.dart']
# Depends on: ['models\\AppModel.ts', 'providers\\Auth.ts']
# Dependencies: ..\..\models\AppModel.ts
# ..\Auth.ts
# --------------------
# views\home\events\CameraView.tsx
# Relevant files: ['views\\home\\events\\CameraView.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\AppModel.ts', 'functions\\Extensions.ts', 'models\\GameModel.ts', 'views\\home\\util\\Permissions.tsx']
# Dependencies: ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\functions\Extensions.ts
# ..\..\..\..\models\GameModel.ts
# ..\..\util\Permissions.tsx
# --------------------
# views\home\team\TeamRowAlliance.tsx
# Relevant files: ['views\\home\\team\\TeamRowAlliance.dart']
# Depends on: ['functions\\Statistics.ts', 'models\\GameModel.ts', 'models\\ScoreModel.ts', 'functions\\Extensions.ts']
# Dependencies: ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\models\GameModel.ts
# ..\..\..\..\models\ScoreModel.ts
# ..\..\..\..\functions\Extensions.ts
# --------------------
# views\home\events\ImageView.tsx
# Relevant files: ['views\\home\\events\\ImageView.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'functions\\Statistics.ts', 'models\\AppModel.ts', 'models\\GameModel.ts']
# Dependencies: ..\..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\..\functions\Statistics.ts
# ..\..\..\..\models\AppModel.ts
# ..\..\..\..\models\GameModel.ts
# --------------------
# views\auth\Verify.tsx
# Relevant files: ['views\\auth\\Verify.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'providers\\Auth.ts']
# Dependencies: ..\..\..\components\misc\PlatformGraphics.tsx
# ..\..\..\providers\Auth.ts
# --------------------
# views\home\team\TeamAllianceRecommend.tsx
# Relevant files: ['views\\home\\team\\TeamAllianceRecommend.dart']
# Depends on: ['models\\GPTModel.ts']
# Dependencies: ..\..\..\..\models\GPTModel.ts
# --------------------
# views\templates\TemplateView.tsx
# Relevant files: ['views\\templates\\TemplateView.dart']
# Depends on: ['models\\GameModel.ts', 'models\\AppModel.ts', 'api\\APIMethods.ts', 'functions\\APIMethods.ts']
# Dependencies: ..\..\..\models\GameModel.ts
# ..\..\..\models\AppModel.ts
# ..\..\..\api\APIMethods.ts
# ..\..\..\functions\APIMethods.ts
# --------------------
# components\misc\InfoPills.tsx
# Relevant files: ['components\\misc\\InfoPills.dart']
# Depends on: []
# Dependencies:
# --------------------
# index.js
# Relevant files: ['main.dart']
# Depends on: ['components\\misc\\PlatformGraphics.tsx', 'models\\GameModel.ts', 'providers\\Auth.ts', 'providers\\PushNotifications.ts', 'providers\\Theme.ts', 'views\\auth\\AuthenticationWrapper.tsx', 'models\\AppModel.ts']
# Dependencies: ..\components\misc\PlatformGraphics.tsx
# ..\models\GameModel.ts
# ..\providers\Auth.ts
# ..\providers\PushNotifications.ts
# ..\providers\Theme.ts
# ..\views\auth\AuthenticationWrapper.tsx
# ..\models\AppModel.ts
# --------------------
# --------------------

# %%
async def make_file(node):
    if node not in target_file_tree.nodes: return None
    if node not in correspondance_graph.nodes:
        print(node)
        return None
    relevant_files = list(correspondance_graph[node])
    depends_on = list(target_dependency_graph[node])
    dependencies = '\n'.join(os.path.relpath(target_file_tree.nodes[file]['path'], os.path.dirname(target_file_tree.nodes[node]['path'])) for file in depends_on)
    custom_context = [
        Interaction(
            prompt=f'Description of {file} in the {target} repo. This file is a dependency of {node}.',
            response=target_file_tree.nodes[file]["description"]
        ) for file in depends_on if file in target_file_tree.nodes and 'content' in target_file_tree.nodes[file]
    ] + [
        Interaction(
            prompt=f'Contents of {file} in the {source} repo',
            response=f'{file}:\n{source_file_tree.nodes[file]["content"]}',
        ) for file in relevant_files if file in source_file_tree.nodes and 'content' in source_file_tree.nodes[file]
    ] + team.context_threads[f'description_{node}']
    raw_resp = await target_swe.async_chat(
        f"The relative dependencies for {node} are\n{dependencies}. Using the context from the prior {source} code (to be translated) and {target} code which {node} depends on, write code in {target} to create {node}. Respond with code and nothing else.",
        custom_context=custom_context
    )
    blocks = extract_markdown_blocks(raw_resp)
    if len(blocks) == 0: return None
    return blocks[0]
nodes = [node for level in target_eval_order for node in level]
tasks = [make_file(node) for node in nodes]
responses = await asyncio.gather(*tasks)
for i, response in enumerate(responses):
    if response is None: continue
    target_file_tree.nodes[nodes[i]]['content'] = response
    with open(f'{working_dir_path}\\{nodes[i]}', 'w') as f:
        f.write(response)

# %%
# Commit the translated code
repo.git.commit(A=True, m=f"Boilerplate {target} code")
repo.git.push('origin', created_branch, force=True)

# Create a pull request with the translated code
pr = create_pull_request(
        repo=repo,
        base_branch=base_branch,
        new_branch=created_branch,
        title=f"Translation from {source} to {target}",
        body=f"This is a boilerplate translation performed by the Fraimwork app. Please check to make sure that all logic is appropriately translated before merging.",
        token=GITHUB_TOKEN
    )

shutil.rmtree('./tmp/', ignore_errors=True)
